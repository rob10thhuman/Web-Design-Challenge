# %%
import pandas as pd

# %%
path = 'Resources/cities.csv'
cities = pd.read_csv(path)
cities
# Out:
#     Unnamed: 0            City      Lat      Long  Max Temp  Humidity  \
# 0            0  ribeira grande  38.5167  -28.7000    294.37        78
# 1            1    punta arenas -53.1500  -70.9167    277.21        87
# 2            2       busselton -33.6500  115.3333    286.53        79
# 3            3       upernavik  72.7868  -56.1549    276.16        84
# 4            4         ushuaia -54.8000  -68.3000    274.94        80
# 5            5  saint-philippe -21.3585   55.7679    296.90        84
# 6            6          rosita  13.9268  -84.4032    304.87        56
# 7            7     port alfred -33.5906   26.8910    289.59        83
# 8            8      bredasdorp -34.5322   20.0403    284.77        87
# 9            9  cabo san lucas  22.8909 -109.9124    310.82        37
# 10          10      nanortalik  60.1432  -45.2371    280.81        66
# 11          11           pevek  69.7008  170.3133    278.82        92
# ...

# %%
table = cities.to_html()

# %%
print(table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Long</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>ribeira grande</td>
#       <td>38.5167</td>
#       <td>-28.7000</td>
#       <td>294.37</td>
#       <td>78</td>
#       <td>20</td>
#       <td>4.63</td>
#       <td>PT</td>
#       <td>1622913894</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>punta arenas</td>
#       <td>-53.1500</td>
#       <td>-70.9167</td>
#       <td>277.21</td>
#       <td>87</td>
#       <td>20</td>
#       <td>3.38</td>
#       <td>CL</td>
#       <td>1622913896</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
# ...
