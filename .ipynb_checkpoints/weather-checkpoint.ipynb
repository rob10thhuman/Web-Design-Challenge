# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress

from api_keys import weather_api_key

from citipy import citipy

output_data_file = "Resources/cities.csv"

lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=20)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=20)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
print(cities)
# Out:
# 18
# ['ribeira grande', 'punta arenas', 'busselton', 'upernavik', 'ushuaia', 'saint-philippe', 'rosita', 'port alfred', 'bredasdorp', 'cabo san lucas', 'nanortalik', 'pevek', 'eyl', 'luderitz', 'mataura', 'alugan', 'klaksvik', 'bluff']

# %%
cities
# Out:
# ['ribeira grande',
#  'punta arenas',
#  'busselton',
#  'upernavik',
#  'ushuaia',
#  'saint-philippe',
#  'rosita',
#  'port alfred',
#  'bredasdorp',
#  'cabo san lucas',
#  'nanortalik',
#  'pevek',
#  'eyl',
#  'luderitz',
#  'mataura',
#  'alugan',
#  'klaksvik',
#  'bluff']

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?'
query_url = url + 'appid=' + weather_api_key + '&q='

# %%
cityname = []
lat = []
lon = []
maxtemp = []
humidity = []
clouds = []
wind = []
country = []
dt = []
lb = '---'
count = 1
gcount = 1

for city in cities: 
    response = requests.get(query_url + city).json()

    try:
        response = requests.get(query_url + city).json()
        print(response)
        cityname.append(response['name'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        maxtemp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        dt.append(response['dt'])
        print(f"Processing Record {count} of Set {groupcount} | {city}")
        count +=1

    except:
        print("City not found.")
        print(response['cod'])
        pass
# Out:
# {'coord': {'lon': -28.7, 'lat': 38.5167}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 294.37, 'feels_like': 294.58, 'temp_min': 294.37, 'temp_max': 294.37, 'pressure': 1029, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 4.63, 'deg': 250}, 'clouds': {'all': 20}, 'dt': 1622913894, 'sys': {'type': 1, 'id': 6883, 'country': 'PT', 'sunrise': 1622874677, 'sunset': 1622927740}, 'timezone': 0, 'id': 3372707, 'name': 'Ribeira Grande', 'cod': 200}
# City not found.
# 200
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 277.16, 'feels_like': 274.19, 'temp_min': 277.1, 'temp_max': 277.21, 'pressure': 1006, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 3.38, 'deg': 284, 'gust': 5.74}, 'clouds': {'all': 20}, 'dt': 1622913896, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1622897407, 'sunset': 1622925278}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# City not found.
# 200
# {'coord': {'lon': 115.3333, 'lat': -33.65}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 286.51, 'feels_like': 285.96, 'temp_min': 286.51, 'temp_max': 286.53, 'pressure': 1017, 'humidity': 79, 'sea_level': 1017, 'grnd_level': 1017}, 'visibility': 10000, 'wind': {'speed': 5.01, 'deg': 287, 'gust': 7.9}, 'clouds': {'all': 16}, 'dt': 1622913898, 'sys': {'type': 2, 'id': 2008303, 'country': 'AU', 'sunrise': 1622935047, 'sunset': 1622971048}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# City not found.
# 200
# {'coord': {'lon': -56.1549, 'lat': 72.7868}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 276.16, 'feels_like': 276.16, 'temp_min': 276.16, 'temp_max': 276.16, 'pressure': 1009, 'humidity': 84, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 1.16, 'deg': 79, 'gust': 1.42}, 'clouds': {'all': 56}, 'dt': 1622913899, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -7200, 'id': 3418910, 'name': 'Upernavik', 'cod': 200}
# City not found.
# 200
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 273.96, 'feels_like': 272.26, 'temp_min': 273.96, 'temp_max': 274.94, 'pressure': 1004, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 1.54, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1622913822, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1622897330, 'sunset': 1622924099}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# City not found.
# 200
# {'coord': {'lon': 55.7679, 'lat': -21.3585}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 294.93, 'feels_like': 295.36, 'temp_min': 294.92, 'temp_max': 296.9, 'pressure': 1019, 'humidity': 84, 'sea_level': 1019, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 2.24, 'deg': 321, 'gust': 3.09}, 'rain': {'1h': 0.32}, 'clouds': {'all': 44}, 'dt': 1622913904, 'sys': {'type': 1, 'id': 2127, 'country': 'RE', 'sunrise': 1622861343, 'sunset': 1622900526}, 'timezone': 14400, 'id': 935215, 'name': 'Saint-Philippe', 'cod': 200}
# City not found.
# 200
# {'coord': {'lon': -84.4032, 'lat': 13.9268}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 304.87, 'feels_like': 308.48, 'temp_min': 304.87, 'temp_max': 304.87, 'pressure': 1013, 'humidity': 56, 'sea_level': 1013, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 1.64, 'deg': 105, 'gust': 4.29}, 'clouds': {'all': 78}, 'dt': 1622913905, 'sys': {'country': 'NI', 'sunrise': 1622891334, 'sunset': 1622937824}, 'timezone': -21600, 'id': 3618337, 'name': 'Rosita', 'cod': 200}
# City not found.
# 200
# {'coord': {'lon': 26.891, 'lat': -33.5906}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 289.59, 'feels_like': 289.46, 'temp_min': 289.59, 'temp_max': 289.59, 'pressure': 1029, 'humidity': 83, 'sea_level': 1029, 'grnd_level': 1027}, 'visibility': 10000, 'wind': {'speed': 6.39, 'deg': 55, 'gust': 10.01}, 'clouds': {'all': 0}, 'dt': 1622913699, 'sys': {'country': 'ZA', 'sunrise': 1622869841, 'sunset': 1622905890}, 'timezone': 7200, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# City not found.
# 200
# {'coord': {'lon': 20.0403, 'lat': -34.5322}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 284.77, 'feels_like': 284.26, 'temp_min': 284.77, 'temp_max': 284.77, 'pressure': 1024, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 0.98, 'deg': 44, 'gust': 1.12}, 'clouds': {'all': 0}, 'dt': 1622913910, 'sys': {'type': 1, 'id': 1966, 'country': 'ZA', 'sunrise': 1622871624, 'sunset': 1622907395}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# City not found.
# 200
# {'coord': {'lon': -109.9124, 'lat': 22.8909}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 305.67, 'feels_like': 305.63, 'temp_min': 305.32, 'temp_max': 310.82, 'pressure': 1014, 'humidity': 37}, 'visibility': 10000, 'wind': {'speed': 4.12, 'deg': 120}, 'clouds': {'all': 1}, 'dt': 1622913861, 'sys': {'type': 1, 'id': 7151, 'country': 'MX', 'sunrise': 1622896434, 'sunset': 1622944970}, 'timezone': -21600, 'id': 3985710, 'name': 'Cabo San Lucas', 'cod': 200}
# City not found.
# 200
# {'coord': {'lon': -45.2371, 'lat': 60.1432}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 280.81, 'feels_like': 277.69, 'temp_min': 280.81, 'temp_max': 280.81, 'pressure': 1005, 'humidity': 66, 'sea_level': 1005, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 5.3, 'deg': 139, 'gust': 8.61}, 'clouds': {'all': 98}, 'dt': 1622913913, 'sys': {'country': 'GL', 'sunrise': 1622871790, 'sunset': 1622938566}, 'timezone': -7200, 'id': 3421765, 'name': 'Nanortalik', 'cod': 200}
# City not found.
# 200
# {'coord': {'lon': 170.3133, 'lat': 69.7008}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 278.82, 'feels_like': 275.13, 'temp_min': 278.82, 'temp_max': 278.82, 'pressure': 997, 'humidity': 92, 'sea_level': 997, 'grnd_level': 991}, 'visibility': 10000, 'wind': {'speed': 5.43, 'deg': 133, 'gust': 7.83}, 'clouds': {'all': 100}, 'dt': 1622913915, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 43200, 'id': 2122090, 'name': 'Pevek', 'cod': 200}
# City not found.
# 200
# {'coord': {'lon': 49.8164, 'lat': 7.9803}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 300.4, 'feels_like': 303.24, 'temp_min': 300.4, 'temp_max': 300.4, 'pressure': 1010, 'humidity': 78, 'sea_level': 1010, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 9.76, 'deg': 200, 'gust': 13.22}, 'clouds': {'all': 51}, 'dt': 1622913916, 'sys': {'country': 'SO', 'sunrise': 1622859743, 'sunset': 1622904982}, 'timezone': 10800, 'id': 60019, 'name': 'Eyl', 'cod': 200}
# City not found.
# 200
# {'coord': {'lon': 15.1594, 'lat': -26.6481}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 293.23, 'feels_like': 292.31, 'temp_min': 293.23, 'temp_max': 293.23, 'pressure': 1017, 'humidity': 39, 'sea_level': 1017, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 3.91, 'deg': 165, 'gust': 5.29}, 'clouds': {'all': 0}, 'dt': 1622913919, 'sys': {'country': 'NA', 'sunrise': 1622871723, 'sunset': 1622909639}, 'timezone': 7200, 'id': 3355672, 'name': 'Lüderitz', 'cod': 200}
# City not found.
# 200
# {'coord': {'lon': 168.8643, 'lat': -46.1927}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 277.37, 'feels_like': 277.37, 'temp_min': 277.37, 'temp_max': 277.37, 'pressure': 1013, 'humidity': 95, 'sea_level': 1013, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 0.23, 'deg': 16, 'gust': 0.39}, 'clouds': {'all': 52}, 'dt': 1622914178, 'sys': {'country': 'NZ', 'sunrise': 1622924435, 'sunset': 1622955962}, 'timezone': 43200, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# City not found.
# 200
# {'coord': {'lon': 125.4808, 'lat': 12.2188}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 298.73, 'feels_like': 299.67, 'temp_min': 298.73, 'temp_max': 298.73, 'pressure': 1008, 'humidity': 89, 'sea_level': 1008, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 1.88, 'deg': 225, 'gust': 2.12}, 'rain': {'1h': 0.56}, 'clouds': {'all': 99}, 'dt': 1622913794, 'sys': {'country': 'PH', 'sunrise': 1622927546, 'sunset': 1622973677}, 'timezone': 28800, 'id': 1731248, 'name': 'Alugan', 'cod': 200}
# City not found.
# 200
# {'coord': {'lon': -6.589, 'lat': 62.2266}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 283.66, 'feels_like': 283.12, 'temp_min': 283.66, 'temp_max': 283.66, 'pressure': 1020, 'humidity': 90, 'sea_level': 1020, 'grnd_level': 1017}, 'visibility': 10000, 'wind': {'speed': 5.88, 'deg': 151, 'gust': 8.87}, 'clouds': {'all': 55}, 'dt': 1622913924, 'sys': {'type': 1, 'id': 1596, 'country': 'FO', 'sunrise': 1622861011, 'sunset': 1622930792}, 'timezone': 3600, 'id': 2618795, 'name': 'Klaksvík', 'cod': 200}
# City not found.
# 200
# {'coord': {'lon': 168.3333, 'lat': -46.6}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 282.18, 'feels_like': 280.27, 'temp_min': 282.18, 'temp_max': 282.18, 'pressure': 1012, 'humidity': 69, 'sea_level': 1012, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 3.39, 'deg': 299, 'gust': 5.06}, 'clouds': {'all': 90}, 'dt': 1622913925, 'sys': {'country': 'NZ', 'sunrise': 1622924654, 'sunset': 1622955997}, 'timezone': 43200, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# City not found.
# 200

# %%
print(str(len(cities)) + " " + str(len(lon)))
# Out:
# 18 18

# %%
weather_dict = {
    "City": cities,
    "Lat": lat,
    "Long": lon,
    "Max Temp": maxtemp,
    "Humidity": humidity,
    "Cloudiness": clouds,
    "Wind Speed": wind,
    "Country": country,
    "Date": dt
}
weather_data = pd.DataFrame(weather_dict)

# %%
weather_data
# Out:
#               City      Lat      Long  Max Temp  Humidity  Cloudiness  \
# 0   ribeira grande  38.5167  -28.7000    294.37        78          20
# 1     punta arenas -53.1500  -70.9167    277.21        87          20
# 2        busselton -33.6500  115.3333    286.53        79          16
# 3        upernavik  72.7868  -56.1549    276.16        84          56
# 4          ushuaia -54.8000  -68.3000    274.94        80          40
# 5   saint-philippe -21.3585   55.7679    296.90        84          44
# 6           rosita  13.9268  -84.4032    304.87        56          78
# 7      port alfred -33.5906   26.8910    289.59        83           0
# 8       bredasdorp -34.5322   20.0403    284.77        87           0
# 9   cabo san lucas  22.8909 -109.9124    310.82        37           1
# 10      nanortalik  60.1432  -45.2371    280.81        66          98
# 11           pevek  69.7008  170.3133    278.82        92         100
# 12             eyl   7.9803   49.8164    300.40        78          51
# 13        luderitz -26.6481   15.1594    293.23        39           0
# 14         mataura -46.1927  168.8643    277.37        95          52
# 15          alugan  12.2188  125.4808    298.73        89          99
# 16        klaksvik  62.2266   -6.5890    283.66        90          55
# 17           bluff -46.6000  168.3333    282.18        69          90
#
#     Wind Speed Country        Date
# 0         4.63      PT  1622913894
# 1         3.38      CL  1622913896
# 2         5.01      AU  1622913898
# 3         1.16      GL  1622913899
# 4         1.54      AR  1622913822
# 5         2.24      RE  1622913904
# 6         1.64      NI  1622913905
# 7         6.39      ZA  1622913699
# 8         0.98      ZA  1622913910
# 9         4.12      MX  1622913861
# 10        5.30      GL  1622913913
# 11        5.43      RU  1622913915
# 12        9.76      SO  1622913916
# 13        3.91      NA  1622913919
# 14        0.23      NZ  1622914178
# 15        1.88      PH  1622913794
# 16        5.88      FO  1622913924
# 17        3.39      NZ  1622913925

# %%
weather_data.to_csv(output_data_file)

# %%
weather_data.describe()
# Out:
#              Lat        Long    Max Temp   Humidity  Cloudiness  Wind Speed  \
# count  18.000000   18.000000   18.000000  18.000000   18.000000   18.000000
# mean    0.548267   24.765928  288.408889  76.277778   45.555556    3.715000
# std    45.249148   92.601807   10.743921  16.928241   36.212156    2.394909
# min   -54.800000 -109.912400  274.940000  37.000000    0.000000    0.230000
# 25%   -34.311650  -53.425450  279.317500  71.250000   17.000000    1.700000
# 50%    -6.689100   17.599850  285.650000  81.500000   47.500000    3.650000
# 75%    34.610250  100.441950  296.267500  87.000000   72.500000    5.227500
# max    72.786800  170.313300  310.820000  95.000000  100.000000    9.760000
#
#                Date
# count  1.800000e+01
# mean   1.622914e+09
# std    9.038885e+01
# min    1.622914e+09
# 25%    1.622914e+09
# 50%    1.622914e+09
# 75%    1.622914e+09
# max    1.622914e+09

# %%
weather_data = weather_data[weather_data['Humidity']<100]
weather_data
# Out:
#               City      Lat      Long  Max Temp  Humidity  Cloudiness  \
# 0   ribeira grande  38.5167  -28.7000    294.37        78          20
# 1     punta arenas -53.1500  -70.9167    277.21        87          20
# 2        busselton -33.6500  115.3333    286.53        79          16
# 3        upernavik  72.7868  -56.1549    276.16        84          56
# 4          ushuaia -54.8000  -68.3000    274.94        80          40
# 5   saint-philippe -21.3585   55.7679    296.90        84          44
# 6           rosita  13.9268  -84.4032    304.87        56          78
# 7      port alfred -33.5906   26.8910    289.59        83           0
# 8       bredasdorp -34.5322   20.0403    284.77        87           0
# 9   cabo san lucas  22.8909 -109.9124    310.82        37           1
# 10      nanortalik  60.1432  -45.2371    280.81        66          98
# 11           pevek  69.7008  170.3133    278.82        92         100
# 12             eyl   7.9803   49.8164    300.40        78          51
# 13        luderitz -26.6481   15.1594    293.23        39           0
# 14         mataura -46.1927  168.8643    277.37        95          52
# 15          alugan  12.2188  125.4808    298.73        89          99
# 16        klaksvik  62.2266   -6.5890    283.66        90          55
# 17           bluff -46.6000  168.3333    282.18        69          90
#
#     Wind Speed Country        Date
# 0         4.63      PT  1622913894
# 1         3.38      CL  1622913896
# 2         5.01      AU  1622913898
# 3         1.16      GL  1622913899
# 4         1.54      AR  1622913822
# 5         2.24      RE  1622913904
# 6         1.64      NI  1622913905
# 7         6.39      ZA  1622913699
# 8         0.98      ZA  1622913910
# 9         4.12      MX  1622913861
# 10        5.30      GL  1622913913
# 11        5.43      RU  1622913915
# 12        9.76      SO  1622913916
# 13        3.91      NA  1622913919
# 14        0.23      NZ  1622914178
# 15        1.88      PH  1622913794
# 16        5.88      FO  1622913924
# 17        3.39      NZ  1622913925

# %%
weather_data.plot(x='Lat', y='Max Temp', kind='scatter', title='Latitude vs Max Temp')
# Out:
# <AxesSubplot:title={'center':'test'}, xlabel='Lat', ylabel='Max Temp'>

# %%
weather_data.plot(x='Lat', y='Humidity', kind='scatter', title='Latitude vs Humidity')
# Out:
# <AxesSubplot:xlabel='Lat', ylabel='Humidity'>

# %%
weather_data.plot(x='Lat', y='Cloudiness', kind='scatter', title='Latitude vs Cloudiness')
# Out:
# <AxesSubplot:xlabel='Lat', ylabel='Cloudiness'>

# %%
weather_data.plot(x='Lat', y='Wind Speed', kind='scatter', title='Latitude vs Wind Speed')
# Out:
# <AxesSubplot:xlabel='Lat', ylabel='Wind Speed'>
